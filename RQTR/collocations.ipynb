# %% [markdown]
# # Collocation Metrics (for Lemmatized Corpora)

# %%
import pathlib
import json
from src.corpus import Corpus
from src.metrics import cooccurrence as co


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Put the path to the directory containing the corpus files here
CORPUSDIR = '/home/brunobrocai/Data/MoWiKo/Paper-themKorp/full'

files = pathlib.Path(CORPUSDIR).iterdir()
data = []
for file in files:
    with open(file, 'r') as f:
        doc = json.load(f)
        data.append(doc['lemmas'])
corpus = Corpus(data)

# %%
# Treating 'künstlich Intelligenz' as one token
corpus.treat_as_one(['künstlich', 'Intelligenz'], 'künstlich_Intelligenz')

# %%
cooccurrences = co.Cooccurrences(window_size=None)
cooccurrences.count_cooccurrences(corpus)
# Out:
# 100%|██████████| 4389/4389 [06:50<00:00, 10.69it/s]

# %%
print(cooccurrences.cooccurrence_table['künstlich_Intelligenz'])
# Out:
# {'künstlich_Intelligenz': 122, 'Bundestag': 1, 'lässt': 33, 'Auswirkung': 14, 'von': 122, 'ChatGPT': 47, 'auf': 113, 'Bildung': 2, 'untersuchen': 14, 'der': 122, 'wollen': 88, 'möglich': 31, 'Software': 35, 'und': 122, 'Forschungsbereich': 3, 'lassen': 49, 'wie': 101, 'Parlament': 2, 'mitteilen': 8, 'haben': 114, 'zuständig': 2, 'Ausschuss': 1, 'für': 122, 'Forschung': 22, 'ein': 122, 'Studie': 13, 'dazu': 59, 'in': 122, 'Auftrag': 2, 'geben': 87, 'demnach': 14, 'sollen': 100, 'sich': 117, 'Expertin': 10, 'Experte': 13, 'Institut': 8, 'Technikfolgenabschätzung': 1, 'Systemanalyse': 1, 'an': 113, 'Karlsruhe': 1, 'Technologie': 43, 'KIT': 1, 'kommend': 24, 'Woche': 44, 'mit': 121, 'Thema': 31, 'beschäftigen': 8, 'dabei': 66, 'sie': 94, 'etwa': 69, 'Entwicklungstrends': 1, 'Anwendungsszenarium': 1, 'ähnlich': 44, 'System': 43, 'Auge': 14, 'fassen': 6, 'unterschiedlich': 21, 'Bereich': 42, 'Wissenschaftssystem': 1, 'wir': 84, 'brauchen': 31, 'umfassend': 9, 'Überblick': 6, 'über': 100, 'technisch': 36, 'ethisch': 11, 'sozial': 23, 'sagen': 89, 'Ausschussvorsitzender': 1, 'Kai': 1, 'Gehring': 1, 'Basis': 21, 'Studienerkenntnisse': 1, 'Parlamentarier': 2, 'Diskussion': 12, 'Konsequenz': 7, 'Forschungspolitik': 1, 'anregen': 7, 'Schule': 10, 'Wissenschaft': 12, 'bis': 74, 'hin': 19, 'zu': 121, 'Weiterbildungssektor': 1, 'Grünenpolitiker': 1, 'öffentlich': 24, 'Sitzung': 1, 'Bildungsausschuss': 1, 'sein': 120, 'April': 2, 'ansetzen': 2, 'US-Unternehmen': 4, 'OpenAI': 43, 'veröffentlichen': 31, 'Chatbot-Prototyp': 1, 'November': 6, 'Programm': 43, 'können': 116, 'auch': 121, 'knapp': 18, 'Anweisung': 6, 'Text': 39, 'schreiben': 51, 'menschlich': 41, 'geschrieben': 4, 'kaum': 20, 'unterscheidbar': 1, 'Google': 55, 'Microsoft': 37, 'Textsoftware': 1, 'integrieren': 28, 'Lehranstalt': 1, 'befürchten': 14, 'Täuschungsversuch': 1, 'nutzen': 50, 'werden': 120, 'bei': 103, 'Studienarbeit': 3, 'herkömmlich': 7, 'Erkennung': 8, 'Plagiat': 4, 'Einsatz': 21, 'nicht': 108, 'erkennen': 41, 'Blase': 7, 'Podcast': 9, 'alle': 71, 'Wirtschaft': 18, 'verstehen': 46, 'nichts': 33, 'Welt': 55, 'Lösung': 16, 'dafür': 48, 'selbst': 48, 'anbieten': 18, 'Entwicklerfirma': 5, 'Anfang': 19, 'Februar': 15, 'ob': 62, 'Mensch': 78, 'oder': 84, 'allerdings': 45, 'gelingen': 21, 'Testläuf': 5, 'bislang': 20, 'nur': 72, 'Viertel': 3, 'Fall': 39, 'räumen': 13, 'Entwickler': 24, 'Konkurrent': 13, 'unter': 65, 'Druck': 13, 'setzen': 36, 'bereits': 55, 'Neuentwicklung': 1, 'reagieren': 15, 'Montag': 12, 'kündigen': 29, 'Alternative': 6, 'Markt': 18, 'bringen': 51, 'Google-Suche': 8, 'neu': 83, 'KI-Funktion': 7, 'erhalten': 23, 'Chatbot': 32, 'Suchmaschine': 22, 'Bing': 17, 'Browser': 3, 'Edge': 3, 'einbauen': 14, 'mal': 15, 'so': 90, 'laut': 39, 'denken': 20, 'Seite': 34, 'was': 47, 'man': 70, 'einst': 3, 'Revolution': 5, 'erwarten': 21, 'Snapchat': 1, 'App': 11, 'wer': 65, 'verschicken': 1, 'posten': 1, 'nach': 83, 'spätestens': 4, 'Stunde': 11, 'wieder': 53, 'verschwinden': 6, 'es': 110, 'Facebooks': 1, 'Angstgegner': 1, 'Wahlkampf': 7, 'aufmischen': 1, 'Fernsehen': 2, 'Hype': 14, 'um': 101, 'lange': 21, 'vorbei': 6, 'Geblieben': 1, 'wofür': 5, 'stehen': 57, 'Story': 3, 'Aneinanderreihung': 1, 'kurz': 25, 'Hochformatig': 1, 'oft': 38, 'tatsächlich': 32, 'relativ': 10, 'spontan': 1, 'produzieren': 22, 'durch': 66, 'Effekt': 5, 'ergänzt': 1, 'Videoclip': 1, 'heute': 34, 'Genre': 2, 'wesentlich': 5, 'Bestandteil': 14, 'jeder': 43, 'groß': 90, 'Netzwerk': 19, 'Instagram': 5, 'Facebook': 8, 'WhatsApp': 3, 'Twitter': 9, 'sogar': 31, 'LinkedIn': 1, 'Nutzerin': 19, 'Nutzer': 40, 'schnell': 42, 'verschwindend': 1, 'Kurzvideo': 1, 'ihr': 84, 'Gefolgschaft': 1, 'Freund': 5, 'geschäftlich': 3, 'Kontakt': 3, 'Funktion': 25, 'machen': 84, 'vor': 89, 'mobil': 1, 'vergänglich': 1, 'Videolastiger': 1, 'entstehen': 17, 'gerade': 39, 'Clubhouse': 1, 'Ende': 23, 'Geschichte': 16, 'noch': 83, 'offen': 14, 'Aufregung': 3, 'erinnern': 13, 'aber': 99, 'zurzeit': 2, 'stark': 33, 'fangen': 1, ' ...

# %%
co.calculate_logdice('künstlich_Intelligenz', 'ATPs', cooccurrences)
# Out:
# 0.42027158604385484

# %%
all_logdice = {
    word: co.calculate_pmi('künstlich_Intelligenz', word, cooccurrences, 0.1)
    for word in cooccurrences.vocab
}

# %%
# Sort the words by their logdice score
sorted_logdice = sorted(all_logdice.items(), key=lambda x: x[1], reverse=True)
print(sorted_logdice[:50])
# Out:
# [('künstlich_Intelligenz', 6.566161361042437), ('Websuche', 5.875176449578379), ('Sprachmodell', 5.778646585457679), ('Sundar', 5.687031861313634), ('Suchmaschine', 5.678098021221443), ('OpenAI', 5.651465440260903), ('Bing', 5.63805070778197), ('Microsoft', 5.617759491625642), ('Sprachmodelle', 5.57877897066161), ('KI-System', 5.529921477900903), ('Chatbot', 5.444212419595041), ('Blogeintrag', 5.386268306916054), ('Trainingsdat', 5.349000832772172), ('Pichai', 5.308385648216466), ('Timnit', 5.2851475255882345), ('ausspucken', 5.259473160354122), ('Bender', 5.253482955536019), ('Emily', 5.227700956233121), ('Softwarekonzern', 5.164510260450562), ('KI-Forschung', 5.163804354606075), ('KI', 5.155759732067905), ('Intelligenz', 5.148478192955514), ('Funktionsweis', 5.1438052917742905), ('Start-ups', 5.139853549302143), ('sprachmodelle', 5.134920881413233), ('ChatGPT', 5.133850854553062), ('Konversation', 5.087297657795766), ('KI-Einsatz', 5.08389152614348), ('Word', 5.056616125000194), ('Algorithm', 5.026066174322178), ('Gewichtung', 4.977679968292677), ('Datensatz', 4.960253852699894), ('trainieren', 4.94966007827495), ('Papagei', 4.935605500960723), ('Wettbewerbsfähigkeit', 4.9030359546875335), ('Hype', 4.882854654313801), ('lernend', 4.868204959777609), ('Abweichung', 4.844994708421656), ('bemissen', 4.803022950525605), ('Intelligenze', 4.789155694261719), ('Googles', 4.782375659236528), ('KI-Gipfel', 4.778785873940115), ('Suchmaschin', 4.759929034573284), ('Techkonzern', 4.750166883095412), ('Language', 4.748834295249126), ('Cloud-Geschäft', 4.72607580178324), ('KI-Unternehme', 4.7230059968418), ('LaMDA', 4.722074921051474), ('Trainingsrunde', 4.721896989666588), ('Zalando', 4.721896989666588)]
